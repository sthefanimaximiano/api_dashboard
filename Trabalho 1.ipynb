# %%
# !pip install dash --user
# Out:
# Requirement already satisfied: dash in c:\users\aluno\appdata\roaming\python\python39\site-packages (2.16.1)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from dash) (5.6.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\programdata\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash) (2.0.0)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from dash) (1.5.5)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from dash) (61.2.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from dash) (4.11.3)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\programdata\anaconda3\lib\site-packages (from dash) (4.1.1)
# Requirement already satisfied: retrying in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash) (1.3.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from dash) (2.27.1)
# Requirement already satisfied: Werkzeug<3.1 in c:\programdata\anaconda3\lib\site-packages (from dash) (2.0.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash) (2.0.0)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=5.1->Flask<3.1,>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->dash) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->dash) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->dash) (2021.10.8)

# %%
# !pip install dash_auth --user
# Out:
# Collecting dash_auth
#   Downloading dash_auth-2.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: werkzeug in c:\programdata\anaconda3\lib\site-packages (from dash_auth) (2.0.3)
# Requirement already satisfied: flask in c:\programdata\anaconda3\lib\site-packages (from dash_auth) (1.1.2)
# Requirement already satisfied: dash>=1.1.1 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash_auth) (2.16.1)
# Requirement already satisfied: nest-asyncio in c:\programdata\anaconda3\lib\site-packages (from dash>=1.1.1->dash_auth) (1.5.5)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from dash>=1.1.1->dash_auth) (61.2.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\lib\site-packages (from dash>=1.1.1->dash_auth) (4.11.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash>=1.1.1->dash_auth) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\programdata\anaconda3\lib\site-packages (from dash>=1.1.1->dash_auth) (4.1.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash>=1.1.1->dash_auth) (2.0.0)
# Requirement already satisfied: retrying in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash>=1.1.1->dash_auth) (1.3.4)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\aluno\appdata\roaming\python\python39\site-packages (from dash>=1.1.1->dash_auth) (5.0.0)
# Requirement already satisfied: plotly>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from dash>=1.1.1->dash_auth) (5.6.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from dash>=1.1.1->dash_auth) (2.27.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from flask->dash_auth) (2.11.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from flask->dash_auth) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from flask->dash_auth) (8.0.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=5.1->flask->dash_auth) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->dash_auth) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=1.1.1->dash_auth) (8.0.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=1.1.1->dash_auth) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata->dash>=1.1.1->dash_auth) (3.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=1.1.1->dash_auth) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=1.1.1->dash_auth) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=1.1.1->dash_auth) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->dash>=1.1.1->dash_auth) (2.0.4)
# Installing collected packages: dash-auth
# Successfully installed dash-auth-2.3.0

# %%
import dash
from dash import Dash, html, dcc
import plotly.express as px  
import pandas as pd
import dash_auth 

#Criando Usuários
usuarios = {"Sthefani": "456"}

#Criando o app dash
app = Dash(__name__)
auth = dash_auth.BasicAuth(app, usuarios)

# Carregue os dados do arquivo Excel
df = pd.read_excel('1 - Base de Dados.xlsx')

df['Data_Pedido'] = pd.to_datetime(df['Data_Pedido'])

df['Mes'] = df['Data_Pedido'].dt.strftime('%B')
display(df)

#Ordenando os meses
ordem_meses = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

#Agrupando os meses e quantidade vendida
df_vendas_mes = df.groupby('Mes')['Quantidade_Vendida'].sum().reset_index()
df_vendas_mes['Mes'] = pd.Categorical(df_vendas_mes['Mes'],  categories=ordem_meses, ordered=True)
df_vendas_mes = df_vendas_mes.sort_values('Mes')

#line para graf de linha e bar para graf de barras 
fig = px.line(df_vendas_mes, x='Mes', y='Quantidade_Vendida',  
             title='Quantidade Total Vendida por Mês',
             labels={'Quantidade_Vendida': 'Quantidade_Vendida', 'Mes': 'Mês'},
             template='plotly_dark')


#Montando a página
app.layout = html.Div([html.Div(children='''Dashboard de Vendas'''),
                      html.H3(children="Quantidade Total Vendida por Mês", id="subtitulo"),
                      dcc.Graph(id='vendas_por_mes', figure=fig)
                      ], style={"text-align": "center"})

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#       Unnamed: 0  ID_Pedido Data_Pedido  ID_Representante Nome_Representante  \
# 0            NaN      10001  2020-01-01              1004   Isabela Carolina
# 1            NaN      10002  2020-01-01              1004   Isabela Carolina
# 2            NaN      10003  2020-01-02              1002        Lucas Souza
# 3            NaN      10004  2020-01-02              1002        Lucas Souza
# 4            NaN      10005  2020-01-02              1005     Tais Fernandes
# ...          ...        ...         ...               ...                ...
# 3206         NaN     200807  2020-12-28              1008    Teobaldo Junior
# 3207         NaN     200808  2020-12-28              1008    Teobaldo Junior
# 3208         NaN     200809  2020-12-29              1006       Mário Junior
# 3209         NaN     200810  2020-12-30              1001        Maria Silva
# 3210         NaN     200811  2020-12-31              1001        Maria Silva
#
#       Regional ID_Produto       Nome_Produto  Valor_Produto  \
# 0      Sudeste    SKU9005   Celular Modelo 3           1800
# 1      Sudeste    SKU9005   Celular Modelo 3           1800
# 2      Sudeste    SKU9011  Notebook Modelo 3           4300
# 3      Sudeste    SKU9011  Notebook Modelo 3           4300
# 4      Sudeste    SKU9008              Mouse             88
# ...        ...        ...                ...            ...
# 3206  Nordeste    SKU9012           Smart TV           1998
# 3207  Nordeste    SKU9015           Teclado              80
# 3208  Nordeste    SKU9005   Celular Modelo 3           1800
# 3209  Nordeste    SKU9006           E-Reader            250
# 3210  Nordeste    SKU9011  Notebook Modelo 3           4300
#
#       Quantidade_Vendida  Valor_Total_Venda    Nome_Cliente  Cidade_Cliente  \
# 0                     21              37800          amazon  Rio de Janeiro
# 1                     57             102600        Shoptime           Betim
# 2                     59             253700       Carrefour  Rio de Janeiro
# 3                     89             382700       Carrefour  Rio de Janeiro
# 4                     71               6248  Ricardo Eletro         Vitória
# ...                  ...                ...             ...             ...
# 3206                  11              21978          amazon        Salvador
# 3207                  20               1600      Ponto Frio        Salvador
# 3208                  71             127800           kabum       Fortaleza
# 3209                  51              12750     Casas Bahia     João Pessoa
# 3210                  41             176300     Casas Bahia           Natal
#
#      Estado_Cliente       Mes
# 0                RJ   January
# 1             MINAS   January
# 2                RJ   January
# 3                RJ   January
# 4                ES   January
# ...             ...       ...
# 3206             BA  December
# 3207             BA  December
# 3208             CE  December
# 3209             PB  December
# 3210             RN  December
#
# [3211 rows x 15 columns]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [3], in <cell line: 43>()
#      38 app.layout = html.Div([html.Div(children='''Dashboard de Vendas'''),
#      39                       html.H3(children="Quantidade Total Vendida por Mês", id="subtitulo"),
#      40                       dcc.Graph(id='vendas_por_mes', figure=fig)
#      41                       ], style={"text-align": "center"})
#      43 if __name__ == '__main__':
# ---> 44     app.run_server(debug=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File C:\ProgramData\Anaconda3\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:378, in JupyterDash.run_app.<locals>.wait_for_app()
#     376 res = req.content.decode()
#     377 if req.status_code != 200:
# --> 378     raise Exception(res)
#     380 if res != "Alive":
#     381     url = f"http://{host}:{port}"
#
# Exception: Login Required

# %%
import dash
from dash import Dash, html, dcc
import plotly.express as px  
import pandas as pd
import dash_auth 

#Criando Usuários
usuarios = {"Sthefani": "456"}

#Criando o app dash
app = Dash(__name__)
auth = dash_auth.BasicAuth(app, usuarios)

# Carregue os dados do arquivo Excel
df = pd.read_excel('1 - Base de Dados.xlsx')

#Agrupando os meses e quantidade vendida
df_sale_rep = df.groupby('Nome_Representante')['Quantidade_Vendida'].sum().reset_index()


fig = px.bar(df_sale_rep, x='Nome_Representante', y='Quantidade_Vendida', color='Nome_Representante', barmode='group')

#Montando a página
app.layout = html.Div([html.Div(children='''Dashboard de Vendas'''),
                      html.H3(children="Vendas por Representante", id="subtitulo"),
                      dcc.Graph(id='vendas_por_mes', figure=fig)
                      ], style={"text-align": "center"})

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [4], in <cell line: 29>()
#      24 app.layout = html.Div([html.Div(children='''Dashboard de Vendas'''),
#      25                       html.H3(children="Vendas por Representante", id="subtitulo"),
#      26                       dcc.Graph(id='vendas_por_mes', figure=fig)
#      27                       ], style={"text-align": "center"})
#      29 if __name__ == '__main__':
# ---> 30     app.run_server(debug=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File C:\ProgramData\Anaconda3\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:378, in JupyterDash.run_app.<locals>.wait_for_app()
#     376 res = req.content.decode()
#     377 if req.status_code != 200:
# --> 378     raise Exception(res)
#     380 if res != "Alive":
#     381     url = f"http://{host}:{port}"
#
# Exception: Login Required
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?

# %%
import dash
from dash import Dash, html, dcc
from dash_table import DataTable
import pandas as pd
import dash_auth

# Criando Usuários
usuarios = {"Sthefani": "456"}

# Criando o app dash
app = Dash(__name__)
auth = dash_auth.BasicAuth(app, usuarios)

# Carregue os dados do arquivo Excel
df = pd.read_excel('1 - Base de Dados.xlsx')

# Agrupando por produto e somando a quantidade vendida
df_vendas_produto = df.groupby('Nome_Produto')['Quantidade_Vendida'].sum().reset_index()

# Criando a tabela de dados
table = DataTable(
    id='table',
    columns=[{"name": i, "id": i} for i in df_vendas_produto.columns],
    data=df_vendas_produto.to_dict('records')
)

# Montando a página
app.layout = html.Div([
    html.Div(children='''Dashboard de Vendas'''),
    html.H3(children="Quantidade Total de Vendas por Produto", id="subtitulo"),
    table
], style={"text-align": "center"})

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [7], in <cell line: 34>()
#      28 app.layout = html.Div([
#      29     html.Div(children='''Dashboard de Vendas'''),
#      30     html.H3(children="Quantidade Total de Vendas por Produto", id="subtitulo"),
#      31     table
#      32 ], style={"text-align": "center"})
#      34 if __name__ == '__main__':
# ---> 35     app.run_server(debug=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File C:\ProgramData\Anaconda3\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:378, in JupyterDash.run_app.<locals>.wait_for_app()
#     376 res = req.content.decode()
#     377 if req.status_code != 200:
# --> 378     raise Exception(res)
#     380 if res != "Alive":
#     381     url = f"http://{host}:{port}"
#
# Exception: Login Required

# %%
import dash
from dash import Dash, html, dcc
import plotly.express as px
import pandas as pd
import dash_auth

# Criando Usuários
usuarios = {"Sthefani": "456"}

# Criando o app dash
app = Dash(__name__)
auth = dash_auth.BasicAuth(app, usuarios)

# Carregue os dados do arquivo Excel
df = pd.read_excel('1 - Base de Dados.xlsx')

# Agrupando por região e somando a quantidade vendida
df_vendas_regiao = df.groupby('Regional')['Quantidade_Vendida'].sum().reset_index()

# Criando o gráfico de pizza
fig = px.pie(df_vendas_regiao, values='Quantidade_Vendida', names='Regional', title='Quantidade de Vendas por Região')

# Montando a página
app.layout = html.Div([
    html.Div(children='''Dashboard de Vendas'''),
    html.H3(children="Quantidade de Vendas por Região", id="subtitulo"),
    dcc.Graph(id='vendas_por_regiao', figure=fig)
], style={"text-align": "center"})

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [6], in <cell line: 30>()
#      24 app.layout = html.Div([
#      25     html.Div(children='''Dashboard de Vendas'''),
#      26     html.H3(children="Quantidade de Vendas por Região", id="subtitulo"),
#      27     dcc.Graph(id='vendas_por_regiao', figure=fig)
#      28 ], style={"text-align": "center"})
#      30 if __name__ == '__main__':
# ---> 31     app.run_server(debug=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File C:\ProgramData\Anaconda3\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:378, in JupyterDash.run_app.<locals>.wait_for_app()
#     376 res = req.content.decode()
#     377 if req.status_code != 200:
# --> 378     raise Exception(res)
#     380 if res != "Alive":
#     381     url = f"http://{host}:{port}"
#
# Exception: Login Required

# %%
import dash
from dash import Dash, html, dcc
import plotly.express as px  
import pandas as pd
import dash_auth 

#Criando Usuários
usuarios = {"Sthefani": "456"}

#Criando o app dash
app = Dash(__name__)
auth = dash_auth.BasicAuth(app, usuarios)

# Carregue os dados do arquivo Excel
df = pd.read_excel('1 - Base de Dados.xlsx')

#Agrupando os meses e quantidade vendida
df_sale_state = df.groupby('Estado_Cliente')['Quantidade_Vendida'].sum().reset_index()


fig = px.bar(df_sale_state, x='Estado_Cliente', y='Quantidade_Vendida', color='Estado_Cliente', barmode='group')

#Montando a página
app.layout = html.Div([html.Div(children='''Dashboard de Vendas'''),
                      html.H3(children="Vendas por Estado", id="subtitulo"),
                      dcc.Graph(id='vendas_por_mes', figure=fig)
                      ], style={"text-align": "center"})

if __name__ == '__main__':
    app.run_server(debug=True)

# %%
import dash
from dash import Dash, html, dcc, Input, Output
import plotly.express as px  
import pandas as pd
import dash_auth 

#Criando Usuários
usuarios = {"Sthefani": "456"}

#Criando o app dash
app = Dash(__name__)
auth = dash_auth.BasicAuth(app, usuarios)

# Carregue os dados do arquivo Excel
df = pd.read_excel('1 - Base de Dados.xlsx')

df['Mes'] = df['Data_Pedido'].dt.strftime('%B')
#display(df)

ordem_meses = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
ordem_meses.append("Todos")

lista_regiao = list(df['Regional'].unique())
lista_regiao.append('Todos')

lista_representante = list(df['Nome_Representante'].unique())
lista_representante.append('Todos')



#Agrupando por mês e somando a quantidade vendida de cada mês
df_vendas_mes = df.groupby(['Mes'])['Quantidade_Vendida'].sum().reset_index()
df_vendas_regiao = df.groupby(['Regional'])['Quantidade_Vendida'].sum().reset_index()
df_sale_rep = df.groupby(['Nome_Representante'])['Quantidade_Vendida'].sum().reset_index()

df_agrupados = df.groupby(['Nome_Produto', 'Mes'])['Quantidade_Vendida'].sum().reset_index()
df_agrupados_regional = df.groupby(['Nome_Produto', 'Regional'])['Quantidade_Vendida'].sum().reset_index()
df_agrupados_representante = df.groupby(['Nome_Produto', 'Nome_Representante'])['Quantidade_Vendida'].sum().reset_index()

fig1 = px.bar(df_vendas_mes, x='Mes', y='Quantidade_Vendida',
             title='Quantidade Total Vendida por Mês', 
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Mes': 'Mês'},
             template='plotly_dark', color="Mes", barmode="group")

fig2 = px.bar(df_vendas_regiao, x='Regional', y='Quantidade_Vendida',
             title='Quantidade Total Vendida por Região',
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Regional': 'Região' },
             template='plotly_dark', color="Regional", barmode="group")

fig3 = px.bar(df_sale_rep, x='Nome_Representante', y='Quantidade_Vendida',
             title='Quantidade de Produto Vendido por Representante',
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Nome_Representante': 'Representante' },
             template='plotly_dark', color="Nome_Representante", barmode="group")

app.layout = html.Div(children=[
    html.H1(children='Visualização de Dados'),
    
    html.Div(children='''Dashboard de Vendas'''),
    
    html.H3(children="Vendas de Cada Mês", id="subtitulo"),
    
    html.Div(children=[dcc.Dropdown(ordem_meses, value="Todos", id='selecao_mes'),
    ], style={"width":"50%", "margin":"auto"}),
    
    dcc.Graph(id='vendas_mes', figure=fig1),
    
    
    html.Div(children=[dcc.Dropdown(lista_regiao, value="Todos", id='selecao_regiao'),
    ], style={"width":"50%", "margin":"auto"}),
    
    dcc.Graph(id='vendas_regiao', figure=fig2),
    
    html.Div(children=[dcc.Dropdown(lista_representante, value="Todos", id='selecao_representante'),
    ], style={"width":"50%", "margin":"auto"}),
    
    dcc.Graph(id='vendas_representante', figure=fig3),

],style={"text-align":"center"})                   
                     
@app.callback(
        Output('subtitulo', 'children'),
        Output('vendas_mes', 'figure'),
        Output('vendas_regiao', 'figure'),
        Output('vendas_representante', 'figure'),
        Input('selecao_mes', 'value'),
        Input('selecao_regiao', 'value'),
        Input('selecao_representante', 'value')
    )

    
def selecionar(mes, regiao, representante):
    if mes == "Todos" and regiao== "Todos" and representante== "Todos":
        texto = "Vendas de Cada Mês"
        fig1 = px.bar(df_vendas_mes, x='Mes', y='Quantidade_Vendida',
             title='Quantidade Total Vendida por Mês', 
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Mes': 'Mês'},
             template='plotly_dark', color="Mes", barmode="group")
        
        fig2 = px.bar(df_vendas_regiao, x='Regional', y='Quantidade_Vendida',
             title='Quantidade Total Vendida por Região',
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Regional': 'Região' },
             template='plotly_dark', color="Regional", barmode="group")
        
        fig3 = px.bar(df_sale_rep, x='Nome_Representante', y='Quantidade_Vendida',
             title='Quantidade de Produto Vendido por Representante',
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Nome_Representante': 'Representante' },
             template='plotly_dark', color="Nome_Representante", barmode="group")
        
    else:
        df_filtrada = df_agrupados
        df_filtrada2 = df_agrupados_regional
        df_filtrada3 = df_agrupados_representante
        if mes != "Todos":
            df_filtrada = df_filtrada.loc[df_filtrada['Mes']==mes, :]
        elif regiao != "Todos":
            df_filtrada2 = df_filtrada2.loc[df_filtrada2['Regional']==regiao, :]
        elif representante != "Todos":
            df_filtrada3 = df_filtrada3.loc[df_filtrada3['Represente']==representante, :]
        
        texto = f"Vendas no Mês de {mes}"
        fig1 = px.bar(df_filtrada, x='Nome_Produto', y='Quantidade_Vendida',
             title='Quantidade Total Vendida por Mês', 
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Mes': 'Mês'},
             template='plotly_dark', color="Nome_Produto", barmode="group")
        
        
        fig2 = px.bar(df_filtrada2, x='Nome_Produto', y='Quantidade_Vendida',
             title='Quantidade Total Vendida por Região',
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Regional': 'Região' },
             template='plotly_dark', color="Nome_Produto", barmode="group")
        
        fig3 = px.bar(df_filtrada3, x='Nome_Produto', y='Quantidade_Vendida',
             title='Quantidade de Produto Vendido por Representante',
             labels={'Quantidade_Vendida': 'Quantidade Vendida', 'Nome_Representante': 'Representante' },
             template='plotly_dark', color="Nome_Produto", barmode="group")
            
    return texto, fig1, fig2, fig3


if __name__ == '__main__':
        app.run_server(debug=False)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [15], in <cell line: 140>()
#     137     return texto, fig1, fig2, fig3
#     140 if __name__ == '__main__':
# --> 141         app.run_server(debug=False)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2223, in Dash.run_server(self, *args, **kwargs)
#    2217 def run_server(self, *args, **kwargs):
#    2218     """`run_server` is a deprecated alias of `run` and may be removed in a
#    2219     future version. We recommend using `app.run` instead.
#    2220
#    2221     See `app.run` for usage information.
#    2222     """
# -> 2223     self.run(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py:2114, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2111             extra_files.append(path)
#    2113 if jupyter_dash.active:
# -> 2114     jupyter_dash.run_app(
#    2115         self,
#    2116         mode=jupyter_mode,
#    2117         width=jupyter_width,
#    2118         height=jupyter_height,
#    2119         host=host,
#    2120         port=port,
#    2121         server_url=jupyter_server_url,
#    2122     )
#    2123 else:
#    2124     self.server.run(host=host, port=port, debug=debug, **flask_run_options)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:404, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     402     display(HTML(msg))
#     403 else:
# --> 404     raise final_error
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:391, in JupyterDash.run_app(self, app, mode, width, height, host, port, server_url)
#     388         raise err
#     390 try:
# --> 391     wait_for_app()
#     393     if self.in_colab:
#     394         JupyterDash._display_in_colab(dashboard_url, port, mode, width, height)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:56, in retry.<locals>.wrap.<locals>.wrapped_f(*args, **kw)
#      54 @six.wraps(f)
#      55 def wrapped_f(*args, **kw):
# ---> 56     return Retrying(*dargs, **dkw).call(f, *args, **kw)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:266, in Retrying.call(self, fn, *args, **kwargs)
#     263 if self.stop(attempt_number, delay_since_first_attempt_ms):
#     264     if not self._wrap_exception and attempt.has_exception:
#     265         # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266         raise attempt.get()
#     267     else:
#     268         raise RetryError(attempt)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:301, in Attempt.get(self, wrap_exception)
#     299         raise RetryError(self)
#     300     else:
# --> 301         six.reraise(self.value[0], self.value[1], self.value[2])
#     302 else:
#     303     return self.value
#
# File C:\ProgramData\Anaconda3\lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File ~\AppData\Roaming\Python\Python39\site-packages\retrying.py:251, in Retrying.call(self, fn, *args, **kwargs)
#     248     self._before_attempts(attempt_number)
#     250 try:
# --> 251     attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252 except:
#     253     tb = sys.exc_info()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py:378, in JupyterDash.run_app.<locals>.wait_for_app()
#     376 res = req.content.decode()
#     377 if req.status_code != 200:
# --> 378     raise Exception(res)
#     380 if res != "Alive":
#     381     url = f"http://{host}:{port}"
#
# Exception: Login Required
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?

# %%
display(df_mes)
# Out:
#           Mes  Quantidade_Vendida
# 0       April               12596
# 1      August               13829
# 2    December               14450
# 3    February               11948
# 4     January               13033
# 5        July               14666
# 6        June               13012
# 7       March               12899
# 8         May               12518
# 9    November               13515
# 10    October               13650
# 11  September               13046
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# WARNING:root:Session is not available. Have you set a secret key?
# ERROR:__main__:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\dash.py", line 1352, in dispatch
#     ctx.run(
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\_callback.py", line 39, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\Aluno\Desktop\websocket\ipykernel_16124\2917056446.py", line 117, in selecionar
#     fig1 = px.bar(df_filtrada, x='Nome_Produto', y='Quantidade_Vendida',
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_chart_types.py", line 368, in bar
#     return make_figure(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1405, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1207, in process_args_into_dataframe
#     raise ValueError(err_msg)
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Mes', 'Quantidade_Vendida'] but received: Nome_Produto
# WARNING:root:Session is not available. Have you set a secret key?
# ERROR:__main__:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\dash.py", line 1352, in dispatch
#     ctx.run(
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\_callback.py", line 39, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\Aluno\Desktop\websocket\ipykernel_16124\2917056446.py", line 117, in selecionar
#     fig1 = px.bar(df_filtrada, x='Nome_Produto', y='Quantidade_Vendida',
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_chart_types.py", line 368, in bar
#     return make_figure(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1405, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1207, in process_args_into_dataframe
#     raise ValueError(err_msg)
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Mes', 'Quantidade_Vendida'] but received: Nome_Produto
# WARNING:root:Session is not available. Have you set a secret key?
# ERROR:__main__:Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\dash.py", line 1352, in dispatch
#     ctx.run(
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\_callback.py", line 450, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)
#   File "C:\Users\Aluno\AppData\Roaming\Python\Python39\site-packages\dash\_callback.py", line 39, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\Aluno\Desktop\websocket\ipykernel_16124\2917056446.py", line 117, in selecionar
#     fig1 = px.bar(df_filtrada, x='Nome_Produto', y='Quantidade_Vendida',
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_chart_types.py", line 368, in bar
#     return make_figure(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1945, in make_figure
#     args = build_dataframe(args, constructor)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1405, in build_dataframe
#     df_output, wide_id_vars = process_args_into_dataframe(
#   File "C:\ProgramData\Anaconda3\lib\site-packages\plotly\express\_core.py", line 1207, in process_args_into_dataframe
#     raise ValueError(err_msg)
# ValueError: Value of 'x' is not the name of a column in 'data_frame'. Expected one of ['Mes', 'Quantidade_Vendida'] but received: Nome_Produto

# %%
import pandas as pd
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import dash_auth

USUARIOS = {
    "Sthefani":"456"
}

app = Dash(__name__) # criando o seu aplicativo Dash
auth = dash_auth.BasicAuth(app, USUARIOS)

# Leitura dos dados
df = pd.read_excel('1 - Base de Dados.xlsx')

# Criação dos filtros
lista_estados = [{'label': estado, 'value': estado} for estado in df['Estado_Cliente'].unique()]

# Layout
app.layout = html.Div(children=[
    html.H1(children='Meu Dashboard'),

    html.Div(children='''
        Dashboard de Vendas em Python 6
    '''),
    
    html.Div([
        html.H3(children="Filtros"),
        dcc.RadioItems(
            id='selecao_estado',
            options=lista_estados,
            value=df['Estado_Cliente'].iloc[0]  # Define o valor padrão como o primeiro estado
        ),
        dcc.Dropdown(
            id='selecao_cidade',
            multi=True
        )
    ]),
    
    dcc.Graph(id='vendas_por_estado')
])

# Callbacks
@app.callback(
    Output('selecao_cidade', 'options'),
    Input('selecao_estado', 'value')
)
def update_cidades_options(selected_estado):
    cidades_estado = df[df['Estado_Cliente'] == selected_estado]['Cidade_Cliente'].unique()
    options = [{'label': cidade, 'value': cidade} for cidade in cidades_estado]
    return options

@app.callback(
    Output('vendas_por_estado', 'figure'),
    Input('selecao_estado', 'value'),
    Input('selecao_cidade', 'value')
)
def update_graph(selected_estado, selected_cidades):
    if selected_cidades is None or len(selected_cidades) == 0:
        # Total de vendas por estado
        vendas_por_estado = df.groupby('Estado_Cliente')['Quantidade_Vendida'].sum().reset_index()
        fig = px.bar(vendas_por_estado, x='Estado_Cliente', y='Quantidade_Vendida', title='Total de Vendas por Estado')
    else:
        # Total de vendas por produto na cidade selecionada
        df_filtrado = df[df['Cidade_Cliente'].isin(selected_cidades)]
        vendas_por_produto = df_filtrado.groupby('Nome_Produto')['Quantidade_Vendida'].sum().reset_index()
        fig = px.bar(vendas_por_produto, x='Nome_Produto', y='Quantidade_Vendida', title='Quantidade Vendida por Produto na(s) Cidade(s) Selecionada(s)')
    return fig

# colocando o seu site (seu dashboard) no ar
if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2780/4042956733.py in <module>
#      70 # colocando o seu site (seu dashboard) no ar
#      71 if __name__ == '__main__':
# ---> 72     app.run_server(debug=False)
#
# ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py in run_server(self, *args, **kwargs)
#    2221         See `app.run` for usage information.
#    2222         """
# -> 2223         self.run(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\dash\dash.py in run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2112
#    2113         if jupyter_dash.active:
# -> 2114             jupyter_dash.run_app(
#    2115                 self,
#    2116                 mode=jupyter_mode,
#
# ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py in run_app(self, app, mode, width, height, host, port, server_url)
#     402                 display(HTML(msg))
#     403             else:
# --> 404                 raise final_error
#     405
#     406     @staticmethod
#
# ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py in run_app(self, app, mode, width, height, host, port, server_url)
#     389
#     390         try:
# --> 391             wait_for_app()
#     392
#     393             if self.in_colab:
#
# ~\AppData\Roaming\Python\Python39\site-packages\retrying.py in wrapped_f(*args, **kw)
#      54             @six.wraps(f)
#      55             def wrapped_f(*args, **kw):
# ---> 56                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      57
#      58             return wrapped_f
#
# ~\AppData\Roaming\Python\Python39\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     264                 if not self._wrap_exception and attempt.has_exception:
#     265                     # get() on an attempt with an exception should cause it to be raised, but raise just in case
# --> 266                     raise attempt.get()
#     267                 else:
#     268                     raise RetryError(attempt)
#
# ~\AppData\Roaming\Python\Python39\site-packages\retrying.py in get(self, wrap_exception)
#     299                 raise RetryError(self)
#     300             else:
# --> 301                 six.reraise(self.value[0], self.value[1], self.value[2])
#     302         else:
#     303             return self.value
#
# C:\ProgramData\Anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     717             if value.__traceback__ is not tb:
#     718                 raise value.with_traceback(tb)
# --> 719             raise value
#     720         finally:
#     721             value = None
#
# ~\AppData\Roaming\Python\Python39\site-packages\retrying.py in call(self, fn, *args, **kwargs)
#     249
#     250             try:
# --> 251                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     252             except:
#     253                 tb = sys.exc_info()
#
# ~\AppData\Roaming\Python\Python39\site-packages\dash\_jupyter.py in wait_for_app()
#     376                 res = req.content.decode()
#     377                 if req.status_code != 200:
# --> 378                     raise Exception(res)
#     379
#     380                 if res != "Alive":
#
# Exception: Login Required
